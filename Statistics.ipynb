# %% [markdown]
# **statistics**

# %% [markdown]
# 1  .  Understanding central Tendency (Easy)
#       A bakery tracks the daily sales of muffins (in dozens) over a week: [10, 12, 11, 15, 14, 13, 12].What is the most representative value of their weekly sales, and why?
#
#  Ans -  (10+12+11+15+14+13+12)/7 = 12.43
#          the value that appears most frequently is 12(twice)
#
# 2  .   Mean in Real Life (Easy)
#        A teacher records the marks of her students in a short quiz: [12, 15, 14, 16, 18, 20, 19].
#        What is the mean score, and what does it tell us about the class’s
#         performance?
#
# Ans   -   sum of score = 12+15+14+16+18+20+19=114
#           Number of student 7
#           score= 144/7 = 16.29
#           the class performance around 16.29 marks this given an idea of the class overall performanc
#
# 3   .   A store records the shoe sizes sold in one day: [7,8,9, 8,8,10,7,9].
#         What is the mode, and why is this information useful for the store manager?
#
# Ans  -   the store sold more 8 shoes then any other size .8 size shoes to
#          meet demand .promotions or displays for 8 size shoes .8 size shoes
#          popular.
#
# 4    .   A car dealer notes the prices of used cars:  [$8,000, $9,500, $10,
#          200, $11,000, $50,000]. Why is the median a better measure than the mean in this case? Calculate the median.
#
# Ans  -  sum of prices =8000+9500+10200+11000+50000=88700
#         number of values = 5
#         mean value = 88700/5 = 17740
#         the mean values 17740 pulled up by the outlier 50000.is less respresentative of typical price the median 10200 gives a better idea of the middle price.
#
# 5    .   A student times how long it takes to finish a puzzle each day:
#           [25, 30, 27, 35, 40].
#           What does the range tell us about the variation in the student’s puzzle-solving time?
#
# Ans   -   Smallest time . 25 minutes
#           larger time   . 40 minutes
#           range = largest-smallest = 40-25 = 15 minutes
#           its means the students pizzels solving time 15 minutes.
#
# 6     .   A farmer records the weekly weight of harvested apples (kg):
#           : [100, 105, 98, 110, 120].
#           Find the range. How can this help the farmer in planning his packaging?
#
# Ans    -   smallest value is 98kg and largest value is 120kg .
#           range = 120-98 = 22kg
#           planning packaging capacity the farmer accommodate for fluctuatons in harvest weaght .understanding variability helps in arranging transport and storage.
#
# 7     .   Two delivery companies track delivery delays (in minutes).
#
#            Company A: variance = 6
#
#            Company B: variance = 15
#            Which company is more consistent, and why?
#
# Ans   -   company A is more consistance
#           the delivery delays are from the average delay .A lower varience mean the delay are more consistence .
#           A has a variance of 6 and B has varience of 15 .company A delivery delay more consistance 6 < 15 .
#
# 8      .  A finance student compares the daily price fluctuations of
#           two cryptocurrencies.
#           Coin A: standard deviation = $30
#           Coin B: standard deviation = $120
#           Which coin is riskier to invest in, and why?
#
# Ans    -  coin B has a higher standard deviation 120 compaired to coin A 30
#           in finance standard deviation is a measure of volatility or risk.
#
# 9     .   A family records their monthly electricity usage (in kWh):
#            [400, 420, 390, 450, 410].Find the mean and standard deviation. What do these values together tell you about the family’s energy use pattern?
#
# Ans    -   the value are given sum = 400+420+390+450+410/5=414
#            the mean of 414 kwh indicates the average monthly electricity
#            usger .
#
# 10     .   A basketball player’s points in 8 games are recorded:
#             [15, 18, 20, 22, 25, 17, 19, 21].
#            Find the mean, median, mode, range, and standard deviation. What insights can these measures provide
#             about the player’s scoring performance?
#
# Ans     -   the number of value are = 15+18+20+22+25+17+19+21/8=19.625
#             the median value is = 19+20/2 = 19.5
#             max-min= 25-15= 10
